# %%
import numpy as np

# %%
#  (   np.dot()     @   np.matmul()   )             * is different

#======================================================================================

#geting help

a = np.arange(6)
# a?
#help(np.arange)

#======================================================================================

a = np.arange(10000)  #(start, stop, step, dtype=None) index type
#print(a)

import sys
np.set_printoptions(threshold=sys.maxsize) # for see the full array
#print(a)

#======================================================================================

a = np.linspace(0, 10, 4)  # 4 numbers from 0 to 10 
#print(a)

#======================================================================================

a = np.random.randint(0, 4, 4).reshape(2,2)
b = np.random.randint(0, 4, 4).reshape(2,2)
#print(a@b)       # matrix product
#print(a.dot(b))  # matrix product
#print(a*b)       # elementwise product

#======================================================================================

a=np.arange(4).reshape(2,2)
# print(a)
# print('////')
# print(a.cumsum(axis=0))   #axis 0 sum row & axis 1 sum column

#======================================================================================

a = np.random.randint(0,7,36).reshape(3,2,2,3)

#a.ravel()     #return 1d array, if edit effect a
#a.flat        #return flatiter object
#a.flatten()   #return a independent 1d array.

# for _ in a.ravel():
#     print(_)     # to see all the element

#======================================================================================

#np.hstack((a,b))  # for horizontal add 2 array
#np.vstack((a,b))  # for horizontal add 2 array
#np.hsplit(a,3)    # split a into 3 horizontal array

#======================================================================================

a = np.arange(18).reshape(3,2,3)
b = a[... , np.newaxis]   # it will increse the dimension by one
#print(b)

#np.flip(  , axis =)  # reverse a array
#np.fromfunction(lambda a,b : 10*a+b, (5,6), dtype=int)

# %%
#np.inner    row*col  row*col   where, col==col and new product shape is row==row

a = np.arange(24).reshape((2,3,4))
b = np.arange(4)

#np.inner(a,b)

# %%
# grayscale image Y= R 0.2126 + G 0.7152 + B 0.0722

# %%
#  (X * Y * Z)  @/np.dot()/np.matmul()  (X1 * Y1)    Z==Y1, NEW MATRIX SHAPE X * Y          3D MAT MUL

# %%
a = np.arange(3*3*3).reshape(3,3,3)
#np.apply_along_axis(lambda b : b[0]+b[-1], 0 , a)
