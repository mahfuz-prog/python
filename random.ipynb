# %%
import random

v = random.random() # float random value each time 0<v<1
v = random.uniform(1,10) # float random value in this range each time
v = random.randint(1, 8) # int random value in this range include 1 & 8

lst=list(range(3))
v = random.choice(lst) # random value from the lst

lst=['mango', 'banana', 'guava']
v = random.choices(lst,weights=[2,2,1], k=10) # return k time random result in a list


deck = set(range(1,33)) #card shuffle and distribute
for _ in range(8):
    deck=list(deck)
    random.shuffle(deck)
    hand=random.sample(deck, k=4)
    x=set(deck)
    deck=x-set(hand)
    print(hand)
# Out:
# [30, 26, 23, 2]
# [18, 25, 20, 27]
# [31, 3, 16, 7]
# [21, 29, 6, 19]
# [14, 17, 5, 1]
# [4, 22, 32, 13]
# [8, 24, 12, 9]
# [15, 10, 28, 11]

# %%
import csv
with open('/content/demo.csv', 'w') as csvfile:
    field_name = ['name', 'age', 'address']
    s = csv.DictWriter(csvfile, fieldnames=field_name)
    s.writeheader()

    s.writerow({'name': 'Mahfuz', 'age': 21, 'address': 'dinajpur'})

# %%
import random
from time import sleep
deck = ['Heart J','Heart 9','Heart A','Heart 10','Heart K','Heart Q','Heart 8','Heart 7','spade J','spade 9','spade A','spade 10','spade K','spade Q','spade 8','spade 7', 'Dimond J', 'Dimond 9', 'Dimond A', 'Dimond 10', 'Dimond K', 'Dimond Q', 'Dimond 8', 'Dimond 7', 'Club J', 'Club 9', 'Club A', 'Club 10', 'Club K', 'Club Q', 'Club 8', 'Club 7']

random.shuffle(deck)
first = deck[:8]
second = deck[8:16]
third = deck[16:24]
fourth = deck[24:]
for i in [4, 8]:
    f = first[:i]
    s = second[0:i]
    t = third[0:i]
    fo = fourth[0:i]

    card_deck = {'f': f, 's': s, 't': t, 'fo': fo}

    sleep(4)
# Out:
# {'f': ['Dimond 8', 'Dimond J', 'spade 8', 'spade A'], 's': ['Club 9', 'Club J', 'Club 7', 'Heart A'], 't': ['Dimond A', 'Club K', 'Club 10', 'Heart 7'], 'fo': ['spade 10', 'Heart J', 'Dimond 10', 'Club A']}
# {'f': ['Dimond 8', 'Dimond J', 'spade 8', 'spade A', 'Club 8', 'spade K', 'Dimond 9', 'spade J'], 's': ['Club 9', 'Club J', 'Club 7', 'Heart A', 'spade 7', 'Heart Q', 'Dimond K', 'Heart 9'], 't': ['Dimond A', 'Club K', 'Club 10', 'Heart 7', 'Heart K', 'spade Q', 'Heart 10', 'Heart 8'], 'fo': ['spade 10', 'Heart J', 'Dimond 10', 'Club A', 'Dimond Q', 'Club Q', 'spade 9', 'Dimond 7']}
