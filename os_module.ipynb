# %%
import os


dir(os.path)


# get current working directory
os.getcwd()

# change directory
#os.chdir('/')

# see all item in current directory
os.listdir()   # pass a directory to see item of this directory

# only create single folder
os.mkdir('folder name')
os.rmdir('folder name')   

# create folder and subfolder
os.makedirs('demo/underdemo')
os.removedirs('demo/underdemo')

# rename file
#os.rename('original file name', 'new file name')

# details of file
os.stat('/content/sample_data/mnist_train_small.csv')   # .st_mtime

# join get environment variable, add new file/folder on this path
os.path.join(os.environ.get('HOME'), 'test.txt')

# it split the directory and the file extension
os.path.splitext('temp/test.txt')

# see only the directory excepting file
os.path.dirname('temp/afdf/test.txt')

# see only the file of a directory
os.path.basename('temp/afdf/test.txt')

# both of dir name and file of a directory
os.path.split('temp/afdf/test.txt')

# identify fake path
os.path.exists('temp/afdf/test.txt')

# to identify directory
os.path.isdir('temp/afdf/test.txt')

# to identify file
os.path.isfile('temp/afdf/test.txt')

# %%
for dirpath, dirnames, filenames in os.walk('/content/sample_data/'):
    print('path : ', dirpath)
    print('directories : ', dirnames)
    print('filename : ', filenames)
# Out:
# path :  /content/sample_data/
# directories :  []
# filename :  ['anscombe.json', 'README.md', 'california_housing_train.csv', 'california_housing_test.csv', 'mnist_test.csv', 'mnist_train_small.csv']
